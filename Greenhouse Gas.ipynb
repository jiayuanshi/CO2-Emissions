# %% [markdown]
# ## CO2 Emmisions Analysis
# The project will focus on the emissions of a specific kind of greenhouse gas -- CO2 and additionally we are going to obtain insights from the relationship between emissions and GDP.

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %% [markdown]
# ### Import & Preprocessing
# First, after importing the dataset, we can see that there are many features measuring different coutries' greenhouse gases level over time. Let's prepare the dataset ready to be used!

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 47410     Zimbabwe  2018      ZWE  15052191.0  2.678627e+10       0.558
# 47411     Zimbabwe  2019      ZWE  15354606.0  2.514642e+10       0.473
# 47412     Zimbabwe  2020      ZWE  15669663.0  2.317871e+10       0.496
# 47413     Zimbabwe  2021      ZWE  15993525.0  2.514009e+10       0.531
# 47414     Zimbabwe  2022      ZWE  16320539.0  2.590159e+10       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 47410                  0.037  10.715           1.419           15.265  ...
# 47411                  0.031   9.775          -0.939           -8.765  ...
# 47412                  0.032   7.850          -1.926          -19.700  ...
# 47413                  0.033   8.396           0.547            6.962  ...
# 47414                  0.033   8.856           0.460            5.477  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         NaN                                   NaN
# 1                         NaN                                 0.157
# 2                         NaN                                 0.156
# 3                         NaN                                 0.156
# 4                         NaN                                 0.155
# ...                       ...                                   ...
# 47410                     NaN                                 0.114
# 47411                     NaN                                 0.113
# 47412                     NaN                                 0.112
# 47413                     NaN                                 0.110
# 47414                     NaN                                 0.110
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                              NaN                          NaN
# 1                            0.000                        0.000
# 2                            0.000                        0.000
# 3                            0.000                        0.000
# 4                            0.000                        0.000
# ...                            ...                          ...
# 47410                        0.001                        0.001
# 47411                        0.001                        0.001
# 47412                        0.001                        0.001
# 47413                        0.001                        0.001
# 47414                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                              NaN                          NaN        NaN
# 1                            0.000                          0.0        NaN
# 2                            0.000                          0.0        NaN
# 3                            0.000                          0.0        NaN
# 4                            0.000                          0.0        NaN
# ...                            ...                          ...        ...
# 47410                        0.002                          0.0     116.76
# 47411                        0.002                          0.0     116.03
# 47412                        0.002                          0.0     113.20
# 47413                        0.002                          0.0        NaN
# 47414                        0.002                          0.0        NaN
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                           NaN        NaN              NaN
# 1                           NaN        NaN              NaN
# 2                           NaN        NaN              NaN
# 3                           NaN        NaN              NaN
# 4                           NaN        NaN              NaN
# ...                         ...        ...              ...
# 47410                     29.37     -0.088           -0.825
# 47411                     28.70      0.143            1.463
# 47412                     25.99      0.818           10.421
# 47413                       NaN      1.088           12.956
# 47414                       NaN        NaN              NaN
#
# [47415 rows x 79 columns]

# %%
# missing values
df = df.fillna(0)

# %%
# applicability: gdp per capita
df['gdp_per_capita'] = np.where(df['population']!=0, df['gdp']/df['population'], 0)

# %%
# make dataframe pipeline interactive
idf = df.interactive()

# %% [markdown]
# ### Emissions over time by continent

# %%
# define panel widgets - time slider
year_slider = pn.widgets.IntSlider(name = 'Year Slider', start = 1750, end = 2022, step = 5, value = 1850)
year_slider
# Out:
# IntSlider(end=2022, name='Year Slider', start=1750, step=5, value=1850)

# %%
# more widgets - radio button
yaxis_co2 = pn.widgets.RadioButtonGroup(name = 'Y axis', options = ['co2', 'co2_per_capita'], button_type = 'success')
yaxis_co2
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['co2', 'co2_per_capita'], value='co2')

# %%
# connect idf with widgets
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) & 
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)
co2_pipeline
# Out:
# <div id='4536'>
#
#
#
#
#
#   <div class="bk-root" id="a89a5578-81f5-4156-b032-422080e7af51" data-root-id="4536"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ef378093-ac99-4755-8dcd-1fe767185a58":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"active":0,"button_type":"success","labels":["co2","co2_per_capita"],"margin":[5,10,5,10]},"id":"4541","type":"RadioButtonGroup"},{"attributes":{"children":[{"id":"4544"}],"margin":[0,0,0,0],"name":"Row36122"},"id":"4543","type":"Row"},{"attributes":{"children":[{"id":"4539"},{"id":"4542"}],"margin":[0,0,0,0],"name":"Row36219"},"id":"4538","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer36218","sizing_mode":"stretch_width"},"id":"4542","type":"Spacer"},{"attributes":{"end":2022,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year Slider","value":1850},"id":"4540","type":"Slider"},{"attributes":{"client_comm_id":"e9cd64666f6c4d1084f15a77967d204e","comm_id":"3636ca552b2a497c86da6f79da6ba719","plot_id":"4536"},"id":"4545","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"4537"}],"margin":[0,0,0,0],"name":"Row36221"},"id":"4536","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame36216","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Africa&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.306&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Oceania&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.306&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;Asia&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;5&lt;/th&gt;\n      &lt;td&gt;North America&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;6&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1751&lt;/td&gt;\n      &lt;td&gt;9.407&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;7&lt;/th&gt;\n      &lt;td&gt;Asia&lt; ...

# %%
# plot
co2_plot = co2_pipeline.hvplot(x='year', by='country', y=yaxis_co2, line_width=2, title='CO2 Emissions by Continent')
co2_plot
# Out:
# /Users/saeroo/opt/anaconda3/lib/python3.9/site-packages/holoviews/core/data/pandas.py:222: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# /Users/saeroo/opt/anaconda3/lib/python3.9/site-packages/holoviews/core/data/pandas.py:222: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# <div id='4546'>
#
#
#
#
#
#   <div class="bk-root" id="a16371f1-9497-4e8f-b342-dbc0a3586e49" data-root-id="4546"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"16bf451b-cfcb-449d-9f1b-5e44ffd49ca6":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"4579","type":"SaveTool"},{"attributes":{"label":{"value":"Europe"},"renderers":[{"id":"4647"}]},"id":"4663","type":"LegendItem"},{"attributes":{"callback":null,"renderers":[{"id":"4604"},{"id":"4625"},{"id":"4647"},{"id":"4671"},{"id":"4697"},{"id":"4725"},{"id":"4755"}],"tags":["hv_created"],"tooltips":[["country","@{country}"],["year","@{year}"],["co2","@{co2}"]]},"id":"4555","type":"HoverTool"},{"attributes":{"data":{"co2":{"__ndarray__":"AAAAAAAAAAA=","dtype":"float64","order":"little","shape":[1]},"country":["South America"],"year":[1850]},"selected":{"id":"4720"},"selection_policy":{"id":"4744"}},"id":"4719","type":"ColumnDataSource"},{"attributes":{},"id":"4750","type":"Selection"},{"attributes":{"label":{"value":"Oceania"},"renderers":[{"id":"4697"}]},"id":"4717","type":"LegendItem"},{"attributes":{"line_color":"#8b8b8b","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"4694","type":"Line"},{"attributes":{},"id":"4580","type":"PanTool"},{"attributes":{"client_comm_id":"37a24d39d1ac45e0893e324477759082","comm_id":"503c580e28e94f809af2aba45c042f90","plot_id":"4546"},"id":"5045","type":"panel.models.comm_manager.CommManager"},{"attributes":{"bottom_units":"screen","coordinates":null,"fill_alpha":0.5,"fill_color":"lightgrey","group":null,"left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","syncable":false,"top_units":"screen"},"id":"4584","type":"BoxAnnotation"},{"attributes":{"line_color":"#e5ae38","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"4644","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#e5ae38","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"4645","type":"Line"},{"attributes":{"children":[{"id":"4549"},{"id":"4552"}],"margin":[0,0,0,0],"name":"Row36524"},"id":"4548","type":"Row"},{"attributes":{"line_color":"#30a2da","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"4601","type":"Line"},{"attributes":{},"id":"4581","type":"WheelZoomTool"},{"attributes":{},"id":"4613","type":"UnionRenderers"},{"attributes":{},"id":"4776","type":"UnionRenderers"},{"attributes":{"overlay":{"id":"4584"}},"id":"4582","type":"BoxZoomTool"},{"attributes":{"line_alpha":0.2,"line_color":"#9467bd","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"4754","type":"Line"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer36523","sizing_mode":"stretch_width"},"id":"4552","type":"Spacer"},{"attributes":{"a ...
